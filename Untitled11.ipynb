# %% [markdown]
# <a href="https://colab.research.google.com/github/ArseniyZu/AlgoTrading/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ta
# Out:
# ...
#   Created wheel for ta: filename=ta-0.7.0-cp37-none-any.whl size=28716 sha256=377be2680252f66ab5784ef8aabc759258e3731ae66e23c99dd633d5c0e73cb3
#   Stored in directory: /root/.cache/pip/wheels/dd/88/30/de9553fb54a474eb7480b937cdbb140bdda613d29cf4da7994
# Successfully built ta
# ...

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3MB 14.3MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=c4a0d490510ffae04d754b751a4ad36589f51807fa49b0fc7a55e9bd48069e9b
#   Stored in directory: /root/.cache/pip/wheels/f8/2a/0f/4b5a86e1d52e451757eb6bc17fd899629f0925c777741b6d04
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
pip install yahoofinancials
# Out:
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-cp37-none-any.whl size=15192 sha256=dbc2e4b63a21c36d8a562b7ab66cfd1a895f9febc03c2fd084e1c22eec8e1451
#   Stored in directory: /root/.cache/pip/wheels/d9/7e/cf/4977a8572d5247242a4b13018d1d36923024ba84236e0d28bc
# Successfully built yahoofinancials
# ...

# %%
from yahoofinancials import YahooFinancials
import yfinance as yf
import ta as ta
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
def drawCandle(df, left, right):
    fig = go.Figure(data=[go.Candlestick(x=[i for i in range(left, right + 1)],
                open=df["Open"][left: right + 1],
                high=df["High"][left: right + 1],
                low=df['Low'][left: right + 1],
                close=df['Close'][left: right + 1])])
    fig.update_layout(title=f"df")
    fig.show()

def drawTrend(df, trendx, trendy):
  fig = go.Figure(data=[go.Candlestick(x=[i for i in range(len(df))],
                open=df["Open"],
                high=df["High"],
                low=df['Low'],
                close=df['Close'])])
  fig.add_trace(go.Scatter(x = trendx, y = trendy,
                mode = "lines", line=go.scatter.Line(color="gray")))
  fig.show()

# %%
TSLA = yf.download('TSLA', period='1y', interval='1d')
TSLA.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2020-06-01  171.600006  179.800003  ...  179.619995  74697500
# 2020-06-02  178.940002  181.731995  ...  176.311996  67828000
# 2020-06-03  177.623993  179.587997  ...  176.591995  39747500
# 2020-06-04  177.975998  179.149994  ...  172.876007  44438500
# 2020-06-05  175.567993  177.304001  ...  177.132004  39059500
#
# [5 rows x 6 columns]

# %%
def trendline(data, ran=30):
  trend = 'non'
  resistance = list()
  support = list()
  start_support = 0
  start_resistance = 0
  data = data[::-1].reset_index(drop=True)
  data = data[:ran]
  max1 = max(data.High[: ran // 3])
  max2 = max(data.High[ran // 3: ran // 3 * 2])
  max3 = max(data.High[ran // 3 * 2:])
  min1 = max(data.Low[: ran // 3])
  min2 = max(data.Low[ran // 3: ran // 3 * 2])
  min3 = max(data.Low[ran // 3 * 2:])
  data = data[data[data.Low == min1].index.to_list()[0]: data[data.Low == min3].index.to_list()[0] + 1]
  if (min1 - min2) + (min2 - min3) >= 2:
    trend = 'up'
  elif (max1 - max2) + (max2 - max3) <= -1:
    trend = 'down'
  else:
    trend = 'flat'
  if trend == 'up':
    start_support = min3
    for i in range(len(data)):
      support.append(start_support + ((min1 - min3) / (len(data))) * i)
    data['support'] = support[::-1]
  data = data[::-1].reset_index(drop=True)
  return (trend, data)

# %%
drawCandle(TSLA, 0, len(TSLA))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9fd8278a-8bc1-477b-808e-95713fd78c23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9fd8278a-8bc1-477b-808e-95713fd78c23")) {
#                     Plotly.newPlot(
#                         '9fd8278a-8bc1-477b-808e-95713fd78c23',
# ...

# %%
TSLA = trendline(TSLA[100:151], 50)[1]
TSLA
# Out:
#           Open        High         Low  ...   Adj Close     Volume     support
# 0   441.920013  445.230011  424.510010  ...  425.790009   39993200  424.510010
# 1   421.839996  422.890015  407.380005  ...  420.630005   33717000  430.363610
# 2   411.630005  425.760010  410.000000  ...  420.279999   28239200  436.217209
# 3   423.760010  430.500000  420.100006  ...  424.679993   22686500  442.070809
# 4   416.480011  418.600006  406.000000  ...  406.019989   25451400  447.924409
# 5   409.959991  418.059998  406.459991  ...  410.829987   22655300  453.778009
# 6   406.899994  407.589996  379.109985  ...  388.040009   42511300  459.631609
# 7   394.000000  406.980011  392.299988  ...  400.510010   29021100  465.485209
# 8   409.730011  427.769989  406.690002  ...  423.899994   34351700  471.338809
# 9   430.619995  435.399994  417.100006  ...  420.980011   32143100  477.192408
# 10  428.299988  440.000000  424.000000  ...  438.089996   28414500  483.046008
# ...

# %%
drawTrend(TSLA, [i for i in range(len(TSLA))], TSLA.support)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="50d345a3-d1dd-4d52-809b-6cd482885730" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("50d345a3-d1dd-4d52-809b-6cd482885730")) {
#                     Plotly.newPlot(
#                         '50d345a3-d1dd-4d52-809b-6cd482885730',
# ...

# %%
TSLA.Close.iloc[-2]
# Out:
# 625.219970703125

# %%
import os

# %%
class Operations():

    def __init__(self, budget):
        self.budget = budget
        self.assets = {}
        self.buy_price = {}

    def sell(self, name, count, price):
        if name in self.assets.keys():
            if self.assets[name] == 0:
                print("No asset in estate")
            elif self.assets[name] >= count:
                self.assets[name] -= count
                self.budget += count * price
                self.buy_price[name] = 0
            else:
                print("Selling counts more than having")
        else:
            print("No asset of this ticker")

    def buy(self, name, count, price):
        if self.budget >= price * count:
            if name not in self.buy_price.keys():
                self.budget -= price * count
                self.buy_price.update({name: price})
                self.assets.update({name: count})
            elif self.buy_price[name] == 0:
                self.budget -= price * count
                self.assets[name] += count
                self.buy_price[name] = price
            else:
                print("Asset already in own")
        else:
            print("No money in budget")

    def stop_loss(self, name, current_price, percentage):
        if (self.buy_price[name] - current_price) / self.buy_price[name] > percentage:
            self.sell(name, self.assets[name], current_price)

    def take_profit(self, name, current_price, percentage):
        if (current_price - self.buy_price[name]) / self.buy_price[name] > percentage:
            self.sell(name, self.assets[name], current_price)

# %%
def isSupport(data):
  support = (data.Low.iloc[-6] > data.Low.iloc[-5] and data.Low.iloc[-5] > data.Low.iloc[-4] 
    and data.Low.iloc[-4] < data.Low.iloc[-3] and data.Low.iloc[-3] < data.Low.iloc[-2])
  return support

def isResistance(data):
  resistance = (data.High.iloc[-6] < data.High.iloc[-5] and data.High.iloc[-5] < data.High.iloc[-4] 
    and data.High.iloc[-4] > data.High.iloc[-3] and data.High.iloc[-3] > data.High.iloc[-2])
  return resistance


def supportLine(data):
  if isSupport(data):
    data["Support"] = data.Low.iloc[-4]
  elif isResistance(data):
    data["Resistance"] = data.High.iloc[-4]
  return data

# %%
(os.path.exists('tickers.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-88873f6464c5> in <module>()
# ----> 1 NOT (os.path.exists('tickers.csv'))
#
# NameError: name 'NOT' is not defined

# %%
last_price_df = {'Last Price': [0]}
last_price_ = pd.DataFrame(data = last_price_df)
last_price_.to_csv('last_price.csv')

# %%
os.remove('last_price.csv')

# %%
last_price_['Last Price'][0] = 100

# %%
last_price_
# Out:
#    Last Price
# 0         100

# %%
def strategy1(data, name, last_price):
  transactions = 0
  new_last_price = 0
  if operation.budget == 0:
    if (last_price - data.Close.iloc[-2]) / last_price > 0.05:
      operation.sell(name, operation.assets[name], data.Open.iloc[-1])
      transactions += 1
  if transactions == 0 and operation.budget > 0 and data.Stoch.iloc[-1] < 20:
    if isSupport(data):
      operation.buy(name, operation.budget / data.Open.iloc[-1], data.Open.iloc[-1])
      transactions += 1
      new_last_price = data.Open.iloc[-1]
  elif operation.budget == 0:
    if isResistance(data) or data.Stoch.iloc[-1] > 80:
      operation.sell(name, operation.assets[name], data.Open.iloc[-1])
      transactions += 1
  return transactions, new_last_price

# %%
tickers = ['MTC', 'FB', 'YNDX', 'ROSN.ME', 'GAZP.ME', 'SBER.ME', 'AFLT.ME', 'LUKOY', 'RTKM.ME', 'TSLA', 'MSNG.ME', 'NVTK.ME']

# %%
def importData(name):
  data = yf.download(name, period='1y', interval='1d')
  return {name: data}

# %%
os.remove('export.csv')

# %%
profit = []
for i in tickers:
  data = importData(i)[i]
  data['Stoch'] = ta.momentum.stochrsi_k(data.Close)
  operation = Operations(10000)
  if os.path.exists('export.csv'):
    pass
  else:
    last_price_df = pd.DataFrame(data = {'Last Price': [0]})
    last_price_df.to_csv('export.csv')
  transactions = 0
  for j in range(10, len(data)):
    last_price_df = pd.read_csv('export.csv') 
    last_price_ = last_price_df['Last Price'][0]
    check = strategy1(data[:j], i, last_price_)
    new_last_price = check[1]
    transactions += check[0]
    os.remove('export.csv')
    last_price_df["Last Price"][0] = new_last_price
    last_price_df.to_csv('export.csv')
  os.remove('export.csv')
  print(transactions)
  profit.append(((operation.budget + operation.assets[i] * data.Open.iloc[-1] - 10000 - transactions * 10000 * 0.001)) / 10000 * 100)
# Out:
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# 13
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# 15
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# Asset already in own
# 13
# ...

# %%
import numpy as np
np.mean(profit)
# Out:
# 29.29495187678099

# %%
profit
# Out:
# [51.990499126691425,
#  15.251959318707122,
#  5.8605692165899015,
#  42.5202098076258,
#  29.744644569094437,
#  19.624394602112517,
#  13.018708754815744,
#  53.04998541235687,
#  9.790041860207657,
#  108.02723593095993,
#  -1.9706273037764004,
#  4.631801225986928]

# %%
strat1 = Operations(10000)
for i in range(50, len(TSLA)):
  strategy1(TSLA[:i], strat1, "TSLA")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# No asset in estate
# ...

# %%
strat1.budget + strat1.assets["TSLA"] * TSLA.Open.iloc[-1]
# Out:
# 10102.384033203125
